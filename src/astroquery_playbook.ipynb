# %%
from astroquery.gaia import Gaia

# %%
job = Gaia.launch_job_async("SELECT count(ra) \
FROM  gaiadr3.gaia_source \
WHERE phot_g_mean_mag < 12")

gtable = job.get_results()
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]

# %%
gtable
# Out:
# <Table length=1>
#  count
#  int64
# -------
# 3087821
